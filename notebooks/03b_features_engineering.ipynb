# %%
# Consolidated imports
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

from libpysal.weights import Queen, lag_spatial

from esda.moran import Moran

from statsmodels.regression.linear_model import OLS
from statsmodels.tools.tools import add_constant
import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LassoCV, RidgeCV

import warnings
warnings.filterwarnings('ignore')

# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # Spatial Feature Engineering Pipeline
#
# **Companion to deck `05-spatial-dependence` (Part 3 — Strategy 1: Spatial Feature
# Engineering).** This notebook makes spatial dependence *explicit in the feature space*:
# it loads cleaned San Francisco block-group data, builds a Queen weights graph, and
# evaluates four spatial feature families — **coordinates**, **spatial lags** (`WX`),
# **Moran eigenvectors** (MESF), and **GCN graph embeddings** — inside an OLS model,
# reporting fit and the **Moran's I of residuals** for each. The residual Moran's I is the
# scoreboard: a good spatial feature drives it toward zero.

# %% [markdown]
# ## 1. Load Cleaned Dataset
# Load tabular and spatial data, merge into a GeoDataFrame, and clean missing/infinite values.

# %%
# Load tabular and spatial data
data = pd.read_csv('data/incidents/InputDataset.csv', dtype={'BGFIPS10': object}).set_index('BGFIPS10')
geo = gpd.read_parquet('data/incidents/SF_BlockGroups10_Cleaned.parquet').set_index('BGFIPS10')
gdf = gpd.GeoDataFrame(data, geometry=geo.geometry)
gdf = gdf.replace([np.inf, -np.inf], np.nan).dropna()

# %% [markdown]
# ## 2. Compute Queen Weights Graph
# Build a Queen contiguity weights object (row-standardized) for use throughout the notebook.

# %%
# Compute Queen weights (row-standardized)
queen = Queen.from_dataframe(gdf, ids=gdf.index, silence_warnings=True)
queen.transform = "R"

# %% [markdown]
# ## 3. Baseline OLS and Moran's I
# Fit a simple OLS model (no spatial features) and compute Moran's I of residuals.

# %%
# Baseline OLS (no spatial features)
YVar = 'DrunkP1k'
XVars = ['pHHPov','BarPSqMi','RetailPSqMi','pMale','VacantHU']
y = gdf[YVar]
X = gdf[XVars]
X = add_constant(X)
fit = OLS(y, X).fit()
print(fit.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               DrunkP1k   R-squared:                       0.286
# Model:                            OLS   Adj. R-squared:                  0.280
# Method:                 Least Squares   F-statistic:                     45.79
# Date:                Tue, 14 Jul 2026   Prob (F-statistic):           8.88e-40
# Time:                        01:29:54   Log-Likelihood:                -2152.3
# No. Observations:                 577   AIC:                             4317.
# Df Residuals:                     571   BIC:                             4343.
# Df Model:                           5
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const         -17.5017      3.062     -5.715      0.000     -23.517     -11.487
# pHHPov          0.1900      0.040      4.801      0.000       0.112       0.268
# BarPSqMi        0.0319      0.012      2.688      0.007       0.009       0.055
# RetailPSqMi     0.0151      0.004      4.269      0.000       0.008       0.022
# pMale           0.2901      0.060      4.860      0.000       0.173       0.407
# VacantHU        0.3683      0.063      5.876      0.000       0.245       0.491
# ==============================================================================
# Omnibus:                      607.851   Durbin-Watson:                   1.767
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            36117.959
# Skew:                           4.775   Prob(JB):                         0.00
# Kurtosis:                      40.564   Cond. No.                     1.33e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.33e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Compute residuals and Moran's I
residuals = y - fit.fittedvalues
moran_baseline = Moran(residuals.values, queen)
print('Baseline residual Moran I:', moran_baseline.I, moran_baseline.p_sim)
# Out:
# Baseline residual Moran I: 0.22244443850300277 0.001

# %%
from splot.esda import plot_moran
plot_moran(moran_baseline, zstandard=True)
plt.title('Moran Plot of Residuals (Baseline OLS)')
plt.show()

# %% [markdown]
# ## 4. Spatial Feature Engineering
# We now compute and add each spatial feature class, then run OLS and Moran's I diagnostics for each.

# %% [markdown]
# ### 4a. Coordinates
# Add centroid coordinates as features and rerun OLS.

# %%
gdf['centroid_x'] = gdf.geometry.centroid.x
gdf['centroid_y'] = gdf.geometry.centroid.y
X_coord = add_constant(gdf[XVars + ['centroid_x', 'centroid_y']])
fit_coord = OLS(y, X_coord).fit()
print(fit_coord.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               DrunkP1k   R-squared:                       0.290
# Model:                            OLS   Adj. R-squared:                  0.281
# Method:                 Least Squares   F-statistic:                     33.23
# Date:                Tue, 14 Jul 2026   Prob (F-statistic):           8.59e-39
# Time:                        01:29:54   Log-Likelihood:                -2150.7
# No. Observations:                 577   AIC:                             4317.
# Df Residuals:                     569   BIC:                             4352.
# Df Model:                           7
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          46.7414     36.768      1.271      0.204     -25.476     118.959
# pHHPov          0.1760      0.040      4.350      0.000       0.097       0.255
# BarPSqMi        0.0308      0.012      2.566      0.011       0.007       0.054
# RetailPSqMi     0.0148      0.004      4.121      0.000       0.008       0.022
# pMale           0.2701      0.061      4.452      0.000       0.151       0.389
# VacantHU        0.3559      0.065      5.489      0.000       0.229       0.483
# centroid_x      0.0003      0.000      1.783      0.075      -3e-05       0.001
# centroid_y  -2.253e-05      0.000     -0.142      0.887      -0.000       0.000
# ==============================================================================
# Omnibus:                      612.668   Durbin-Watson:                   1.764
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            37903.269
# Skew:                           4.823   Prob(JB):                         0.00
# Kurtosis:                      41.517   Cond. No.                     1.89e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.89e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Compute residuals and Moran's I for coordinates model
res_coord = y - fit_coord.fittedvalues
moran_coord = Moran(res_coord.values, queen)
print('Residual Moran I (coords):', moran_coord.I, moran_coord.p_sim)
# Out:
# Residual Moran I (coords): 0.22322033861061832 0.001

# %%
# Plot Moran's I of residuals for coordinates model
from splot.esda import plot_moran
plot_moran(Moran(res_coord.values, queen), zstandard=True)
plt.title('Moran Plot of Residuals (Coordinates)')
plt.show()

# %% [markdown]
# ### 4b. Spatial Lag of Explanatory Variables
# Add spatial lag features for each explanatory variable and rerun OLS.

# %%
def spatial_lag(df, columns, w):
    lagged = {}
    for col in columns:
        lagged[f"{col}_lag"] = lag_spatial(w, df[col].values)
    return pd.DataFrame(lagged, index=df.index)

# Compute spatial lags and add to gdf
gdf_lags = spatial_lag(gdf, XVars, queen)
for col in gdf_lags.columns:
    gdf[col] = gdf_lags[col]
X_lag = add_constant(gdf[XVars + list(gdf_lags.columns)])
fit_lag = OLS(y, X_lag).fit()
print(fit_lag.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               DrunkP1k   R-squared:                       0.328
# Model:                            OLS   Adj. R-squared:                  0.317
# Method:                 Least Squares   F-statistic:                     27.68
# Date:                Tue, 14 Jul 2026   Prob (F-statistic):           3.86e-43
# Time:                        01:29:55   Log-Likelihood:                -2134.7
# No. Observations:                 577   AIC:                             4291.
# Df Residuals:                     566   BIC:                             4339.
# Df Model:                          10
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const             -34.5921      5.340     -6.478      0.000     -45.080     -24.104
# pHHPov              0.1055      0.047      2.250      0.025       0.013       0.198
# BarPSqMi            0.0261      0.013      2.081      0.038       0.001       0.051
# RetailPSqMi         0.0161      0.004      4.162      0.000       0.009       0.024
# pMale               0.1938      0.064      3.013      0.003       0.067       0.320
# VacantHU            0.3060      0.063      4.878      0.000       0.183       0.429
# pHHPov_lag          0.1875      0.075      2.496      0.013       0.040       0.335
# BarPSqMi_lag       -0.0628      0.024     -2.650      0.008      -0.109      -0.016
# RetailPSqMi_lag     0.0080      0.008      1.025      0.306      -0.007       0.023
# pMale_lag           0.3612      0.112      3.224      0.001       0.141       0.581
# VacantHU_lag        0.4298      0.139      3.083      0.002       0.156       0.704
# ==============================================================================
# Omnibus:                      614.556   Durbin-Watson:                   1.806
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            38831.428
# Skew:                           4.839   Prob(JB):                         0.00
# Kurtosis:                      42.006   Cond. No.                     2.87e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.87e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Compute residuals and Moran's I for spatial lag model
res_lag = y - fit_lag.fittedvalues
moran_lag = Moran(res_lag.values, queen)
print('Residual Moran I (spatial lag):', moran_lag.I, moran_lag.p_sim)
# Out:
# Residual Moran I (spatial lag): 0.19706339971695408 0.001

# %%
# Plot Moran's I of residuals for spatial lag model
plot_moran(Moran(res_lag.values, queen), zstandard=True)
plt.title('Moran Plot of Residuals (Spatial Lag)')
plt.show()

# %% [markdown]
# ### 4c. Moran Eigenvector Spatial Filtering (MESF)
#
# This is the deck's **MSEF** slide (Approach 1): eigenvectors of the double-centred
# weights matrix $B = CWC$ form an orthogonal spatial basis (broad to fine scale); adding
# the top-$k$ as regressors absorbs residual spatial structure (Griffith 2003; Dray et
# al. 2006). We add the top eigenvectors as features, then rerun OLS.

# %%
def compute_mesf(gdf, w, k=10):
    idx = gdf.index.to_list()
    n = len(idx)
    A = w.full()[0]
    I = np.eye(n)
    one = np.ones((n, 1))
    M = I - (one @ one.T) / n
    S = 0.5 * (M @ A @ M + M @ A.T @ M)
    evals, evecs = np.linalg.eigh(S)
    order = np.argsort(evals)[::-1]
    evals, evecs = evals[order], evecs[:, order]
    mem_cols = [f'MEM_{i}' for i in range(k)]
    mem_df = pd.DataFrame(evecs[:, :k], index=gdf.index, columns=mem_cols)
    return mem_df

# Compute MESF and add to gdf
mem_df = compute_mesf(gdf, queen, k=50)
for col in mem_df.columns:
    gdf[col] = mem_df[col]
X_mesf = add_constant(gdf[XVars + list(mem_df.columns)])
fit_mesf = OLS(y, X_mesf).fit()
print(fit_mesf.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               DrunkP1k   R-squared:                       0.478
# Model:                            OLS   Adj. R-squared:                  0.423
# Method:                 Least Squares   F-statistic:                     8.682
# Date:                Tue, 14 Jul 2026   Prob (F-statistic):           1.78e-45
# Time:                        01:29:55   Log-Likelihood:                -2061.9
# No. Observations:                 577   AIC:                             4236.
# Df Residuals:                     521   BIC:                             4480.
# Df Model:                          55
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          -8.9185      3.363     -2.652      0.008     -15.525      -2.312
# pHHPov          0.0836      0.047      1.790      0.074      -0.008       0.175
# BarPSqMi        0.0381      0.013      3.026      0.003       0.013       0.063
# RetailPSqMi     0.0144      0.004      4.097      0.000       0.007       0.021
# pMale           0.1627      0.064      2.542      0.011       0.037       0.288
# VacantHU        0.2575      0.061      4.221      0.000       0.138       0.377
# MEM_45          8.7975      9.106      0.966      0.334      -9.092      26.687
# MEM_46         10.9457      9.181      1.192      0.234      -7.090      28.982
# MEM_47        -25.6213      9.108     -2.813      0.005     -43.515      -7.728
# MEM_48        -32.4152      9.228     -3.513      0.000     -50.543     -14.287
# MEM_49        -10.1163      9.230     -1.096      0.274     -28.249       8.016
# ==============================================================================
# Omnibus:                      523.497   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            22984.815
# Skew:                           3.818   Prob(JB):                         0.00
# Kurtosis:                      32.962   Cond. No.                     6.69e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.69e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Compute residuals and Moran's I for MESF model
res_mesf = y - fit_mesf.fittedvalues
moran_mesf = Moran(res_mesf.values, queen)
print('Residual Moran I (MESF):', moran_mesf.I, moran_mesf.p_sim)
# Out:
# Residual Moran I (MESF): 0.016701353101938567 0.207

# %%
# Plot Moran's I of residuals for MESF model
plot_moran(Moran(res_mesf.values, queen), zstandard=True)
plt.title('Moran Plot of Residuals (MESF)')
plt.show()

# %% [markdown]
# ### 4d. Graph Embeddings with PyTorch Geometric GCN
# In this section, we use a GCN autoencoder to generate spatial graph embeddings for each block group. We first define the model, then perform a grid search to select the optimal embedding size, and finally run the optimized model to generate features for OLS regression.

# %% [markdown]
# #### Step 1: Define the GCN Autoencoder Model
# We first define the GCN autoencoder architecture, which will be used to learn node embeddings from the Queen contiguity graph and explanatory variables.

# %%
# Prepare node features: explanatory variables only
scaler = StandardScaler()
X_feats = scaler.fit_transform(gdf[XVars])
x = torch.tensor(X_feats, dtype=torch.float32)

# Graph structure from Queen weights
G_nx = queen.to_networkx()
edge_index = torch.tensor(list(G_nx.edges)).t().contiguous()

# Define GCN autoencoder model
class GCN_AE(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels):
        super().__init__()
        self.encoder = GCNConv(in_channels, hidden_channels)
        self.decoder = torch.nn.Linear(hidden_channels, in_channels)
    def forward(self, x, edge_index):
        z = F.relu(self.encoder(x, edge_index))
        x_hat = self.decoder(z)
        return x_hat, z

# %% [markdown]
# #### Step 2: Grid Search for Optimal Embedding Size
# We perform a grid search over several candidate embedding sizes (e.g., 4, 8, 16, 32, 48, 64, 128). For each size, we train the autoencoder, use the embeddings as features in OLS, and record model fit (AIC) and residual spatial autocorrelation (Moran's I and p-value).

# %%
# Grid search for best embedding size
dims = [4, 8, 16, 32, 48, 64, 128]
results = []

for dim in dims:
    # Train GCN autoencoder with 'dim' hidden units
    model = GCN_AE(x.shape[1], dim)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
    for epoch in range(200):
        model.train()
        optimizer.zero_grad()
        x_hat, z = model(x, edge_index)
        loss = F.mse_loss(x_hat, x)
        loss.backward()
        optimizer.step()
    embeddings = z.detach().numpy()
    for i in range(embeddings.shape[1]):
        gdf[f'gcn_ae_embed_{i}'] = embeddings[:, i]
    X_gcn_ae = add_constant(gdf[XVars + [f'gcn_ae_embed_{i}' for i in range(embeddings.shape[1])]])
    fit_gcn_ae = OLS(y, X_gcn_ae).fit()
    print(f'Embedding dim {dim} OLS summary:')
    print(fit_gcn_ae.summary())
# Out:
# Embedding dim 4 OLS summary:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               DrunkP1k   R-squared:                       0.318
# Model:                            OLS   Adj. R-squared:                  0.307
# Method:                 Least Squares   F-statistic:                     29.38
# Date:                Tue, 14 Jul 2026   Prob (F-statistic):           4.76e-42
# Time:                        01:29:55   Log-Likelihood:                -2139.2
# No. Observations:                 577   AIC:                             4298.
# Df Residuals:                     567   BIC:                             4342.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -7.4946      4.958     -1.512      0.131     -17.233       2.244
# pHHPov             0.1397      0.049      2.847      0.005       0.043       0.236
# BarPSqMi           0.0111      0.013      0.869      0.385      -0.014       0.036
# RetailPSqMi        0.0161      0.004      3.826      0.000       0.008       0.024
# pMale              0.1312      0.074      1.765      0.078      -0.015       0.277
# VacantHU           0.2296      0.070      3.296      0.001       0.093       0.366
# gcn_ae_embed_0     2.4972      1.465      1.705      0.089      -0.380       5.374
# gcn_ae_embed_1    -4.7832      4.523     -1.058      0.291     -13.666       4.100
# gcn_ae_embed_2    -3.2251      1.026     -3.143      0.002      -5.240      -1.210
# gcn_ae_embed_3     2.0238      0.791      2.558      0.011       0.470       3.578
# ==============================================================================
# Omnibus:                      616.484   Durbin-Watson:                   1.790
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            41470.655
# Skew:                           4.836   Prob(JB):                         0.00
# Kurtosis:                      43.391   Cond. No.                     2.31e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.31e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Embedding dim 8 OLS summary:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               DrunkP1k   R-squared:                       0.378
# Model:                            OLS   Adj. R-squared:                  0.364
# Method:                 Least Squares   F-statistic:                     26.33
# Date:                Tue, 14 Jul 2026   Prob (F-statistic):           4.64e-50
# Time:                        01:29:55   Log-Likelihood:                -2112.6
# No. Observations:                 577   AIC:                             4253.
# Df Residuals:                     563   BIC:                             4314.
# Df Model:                          13
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              5.5155      6.000      0.919      0.358      -6.270      17.301
# pHHPov             0.0721      0.053      1.352      0.177      -0.033       0.177
# BarPSqMi           0.0314      0.014      2.259      0.024       0.004       0.059
# RetailPSqMi        0.0160      0.004      3.661      0.000       0.007       0.025
# pMale              0.1596      0.072      2.224      0.027       0.019       0.301
# VacantHU           0.2352      0.069      3.418      0.001       0.100       0.370
# gcn_ae_embed_0     0.0681      1.542      0.044      0.965      -2.961       3.098
# gcn_ae_embed_1    11.8196      1.852      6.384      0.000       8.183      15.456
# gcn_ae_embed_2    -9.0638      3.326     -2.725      0.007     -15.597      -2.531
# gcn_ae_embed_3    -5.7692      1.749     -3.299      0.001      -9.204      -2.335
# gcn_ae_embed_4    -7.1599      2.995     -2.391      0.017     -13.042      -1.278
# gcn_ae_embed_5    -2.9455      1.426     -2.066      0.039      -5.746      -0.145
# gcn_ae_embed_6   -10.4544      3.039     -3.440      0.001     -16.423      -4.486
# gcn_ae_embed_7    -4.3505      2.393     -1.818      0.070      -9.051       0.351
# ==============================================================================
# Omnibus:                      592.942   Durbin-Watson:                   1.920
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            33728.776
# Skew:                           4.592   Prob(JB):                         0.00
# Kurtosis:                      39.312   Cond. No.                     3.35e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.35e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Embedding dim 16 OLS summary:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               DrunkP1k   R-squared:                       0.393
# Model:                            OLS   Adj. R-squared:                  0.370
# Method:                 Least Squares   F-statistic:                     17.08
# Date:                Tue, 14 Jul 2026   Prob (F-statistic):           2.10e-47
# Time:                        01:29:55   Log-Likelihood:                -2105.8
# No. Observations:                 577   AIC:                             4256.
# Df Residuals:                     555   BIC:                             4351.
# Df Model:                          21
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               0.8749      6.606      0.132      0.895     -12.101      13.851
# pHHPov              0.0701      0.054      1.309      0.191      -0.035       0.175
# BarPSqMi            0.0339      0.014      2.399      0.017       0.006       0.062
# RetailPSqMi         0.0169      0.004      3.838      0.000       0.008       0.026
# pMale               0.1855      0.072      2.586      0.010       0.045       0.326
# VacantHU            0.2467      0.070      3.548      0.000       0.110       0.383
# gcn_ae_embed_0     -7.0051      4.158     -1.685      0.093     -15.172       1.161
# gcn_ae_embed_1    -19.0764      5.708     -3.342      0.001     -30.289      -7.864
# gcn_ae_embed_2     -5.1311      4.727     -1.085      0.278     -14.417       4.155
# gcn_ae_embed_3      2.6228      7.947      0.330      0.742     -12.988      18.233
# gcn_ae_embed_4      6.6928      3.244      2.063      0.040       0.321      13.065
# gcn_ae_embed_5      1.3359      3.784      0.353      0.724      -6.096       8.768
# gcn_ae_embed_6     -6.6693      6.407     -1.041      0.298     -19.254       5.915
# gcn_ae_embed_7     -1.6426      6.186     -0.266      0.791     -13.793      10.508
# gcn_ae_embed_8     -2.2019      5.259     -0.419      0.676     -12.532       8.128
# gcn_ae_embed_9      6.9836      3.121      2.238      0.026       0.853      13.114
# gcn_ae_embed_10    -3.0820      2.872     -1.073      0.284      -8.723       2.559
# gcn_ae_embed_11    -8.5395      6.881     -1.241      0.215     -22.055       4.976
# gcn_ae_embed_12     3.1643      4.121      0.768      0.443      -4.930      11.258
# gcn_ae_embed_13     8.8431      3.851      2.296      0.022       1.279      16.407
# gcn_ae_embed_14    -1.9687      3.556     -0.554      0.580      -8.954       5.016
# gcn_ae_embed_15    -7.2618      3.921     -1.852      0.065     -14.963       0.439
# ==============================================================================
# Omnibus:                      581.574   Durbin-Watson:                   1.952
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            31273.405
# Skew:                           4.466   Prob(JB):                         0.00
# Kurtosis:                      37.943   Cond. No.                     5.41e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.41e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Embedding dim 32 OLS summary:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               DrunkP1k   R-squared:                       0.458
# Model:                            OLS   Adj. R-squared:                  0.421
# Method:                 Least Squares   F-statistic:                     12.32
# Date:                Tue, 14 Jul 2026   Prob (F-statistic):           9.61e-51
# Time:                        01:29:56   Log-Likelihood:                -2072.8
# No. Observations:                 577   AIC:                             4222.
# Df Residuals:                     539   BIC:                             4387.
# Df Model:                          37
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const             -23.0002      6.767     -3.399      0.001     -36.292      -9.708
# pHHPov              0.0511      0.053      0.965      0.335      -0.053       0.155
# BarPSqMi            0.0347      0.014      2.465      0.014       0.007       0.062
# RetailPSqMi         0.0134      0.004      3.088      0.002       0.005       0.022
# pMale               0.2149      0.070      3.051      0.002       0.077       0.353
# VacantHU            0.2630      0.068      3.855      0.000       0.129       0.397
# gcn_ae_embed_0     26.7813     15.086      1.775      0.076      -2.854      56.416
# gcn_ae_embed_1     36.5705     11.503      3.179      0.002      13.975      59.166
# gcn_ae_embed_2     -5.1566      6.121     -0.842      0.400     -17.181       6.868
# gcn_ae_embed_3    -17.0484     14.778     -1.154      0.249     -46.077      11.981
# gcn_ae_embed_4    -16.7759     10.053     -1.669      0.096     -36.523       2.971
# gcn_ae_embed_38   143.4682    110.387      1.300      0.194     -73.388     360.324
# gcn_ae_embed_39     7.6738      7.807      0.983      0.326      -7.662      23.010
# gcn_ae_embed_40    -5.0215     15.050     -0.334      0.739     -34.587      24.544
# gcn_ae_embed_41    16.6273     22.192      0.749      0.454     -26.970      60.224
# gcn_ae_embed_42    -5.0376     10.207     -0.494      0.622     -25.090      15.015
# gcn_ae_embed_43    -5.5788     12.544     -0.445      0.657     -30.221      19.064
# gcn_ae_embed_44    16.2404     17.392      0.934      0.351     -17.926      50.406
# gcn_ae_embed_45    -1.9460     15.106     -0.129      0.898     -31.622      27.730
# gcn_ae_embed_46   -23.7074     13.209     -1.795      0.073     -49.657       2.242
# gcn_ae_embed_47    -0.8793     11.072     -0.079      0.937     -22.630      20.872
# ==============================================================================
# Omnibus:                      471.840   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            14141.448
# Skew:                           3.377   Prob(JB):                         0.00
# Kurtosis:                      26.294   Cond. No.                     1.38e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.02e-25. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Embedding dim 64 OLS summary:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               DrunkP1k   R-squared:                       0.488
# Model:                            OLS   Adj. R-squared:                  0.419
# Method:                 Least Squares   F-statistic:                     7.120
# Date:                Tue, 14 Jul 2026   Prob (F-statistic):           1.90e-41
# Time:                        01:29:56   Log-Likelihood:                -2056.5
# No. Observations:                 577   AIC:                             4251.
# Df Residuals:                     508   BIC:                             4552.
# Df Model:                          68
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const              -6.5544     15.999     -0.410      0.682     -37.987      24.879
# pHHPov              0.0791      0.055      1.442      0.150      -0.029       0.187
# BarPSqMi            0.0271      0.015      1.753      0.080      -0.003       0.058
# RetailPSqMi         0.0163      0.005      3.473      0.001       0.007       0.026
# pMale               0.1971      0.073      2.689      0.007       0.053       0.341
# VacantHU            0.2575      0.070      3.667      0.000       0.120       0.395
# gcn_ae_embed_0     -7.6877     13.910     -0.553      0.581     -35.017      19.641
# gcn_ae_embed_1     21.4690     11.557      1.858      0.064      -1.237      44.175
# gcn_ae_embed_2     28.7586      7.815      3.680      0.000      13.405      44.112
# gcn_ae_embed_3      8.5637     20.516      0.417      0.677     -31.742      48.870
# gcn_ae_embed_4     35.1102     26.788      1.311      0.191     -17.519      87.740
# gcn_ae_embed_5     -5.6264     11.489     -0.490      0.625     -28.197      16.944
# gcn_ae_embed_6     10.7976     16.012      0.674      0.500     -20.661      42.256
# gcn_ae_embed_7      8.4578     18.780      0.450      0.653     -28.437      45.353
# gcn_ae_embed_8    -50.4534     21.366     -2.361      0.019     -92.429      -8.478
# gcn_ae_embed_9    -16.1001     15.287     -1.053      0.293     -46.133      13.932
# gcn_ae_embed_10    44.8363     13.859      3.235      0.001      17.609      72.064
# gcn_ae_embed_11     8.6470     16.203      0.534      0.594     -23.186      40.480
# gcn_ae_embed_12    10.8114     23.433      0.461      0.645     -35.227      56.849
# gcn_ae_embed_13   -14.9041     18.922     -0.788      0.431     -52.080      22.272
# gcn_ae_embed_14   -13.8008      9.165     -1.506      0.133     -31.806       4.204
# gcn_ae_embed_15     2.2109     18.132      0.122      0.903     -33.412      37.834
# gcn_ae_embed_16   2.46e-14   3.84e-14      0.641      0.522   -5.08e-14       1e-13
# gcn_ae_embed_55   -18.5364     12.780     -1.450      0.148     -43.644       6.571
# gcn_ae_embed_56   -12.9740     25.932     -0.500      0.617     -63.921      37.973
# gcn_ae_embed_57    -7.1664     16.521     -0.434      0.665     -39.623      25.291
# gcn_ae_embed_58   -15.9002     24.145     -0.659      0.511     -63.337      31.537
# gcn_ae_embed_59   -23.4105     29.985     -0.781      0.435     -82.320      35.499
# gcn_ae_embed_60    28.3158     22.171      1.277      0.202     -15.242      71.874
# gcn_ae_embed_61   -57.5766     38.858     -1.482      0.139    -133.919      18.765
# gcn_ae_embed_62     1.3139      8.986      0.146      0.884     -16.340      18.967
# gcn_ae_embed_63    -3.5481      5.646     -0.628      0.530     -14.640       7.543
# ==============================================================================
# Omnibus:                      469.272   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            13332.106
# Skew:                           3.371   Prob(JB):                         0.00
# Kurtosis:                      25.563   Cond. No.                     1.38e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.02e-25. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Embedding dim 128 OLS summary:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               DrunkP1k   R-squared:                       0.675
# Model:                            OLS   Adj. R-squared:                  0.577
# Method:                 Least Squares   F-statistic:                     6.908
# Date:                Tue, 14 Jul 2026   Prob (F-statistic):           3.51e-54
# Time:                        01:29:56   Log-Likelihood:                -1925.6
# No. Observations:                 577   AIC:                             4119.
# Df Residuals:                     443   BIC:                             4703.
# Df Model:                         133
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               -6.1279     18.025     -0.340      0.734     -41.554      29.298
# pHHPov               0.0152      0.054      0.283      0.777      -0.090       0.121
# BarPSqMi             0.0096      0.017      0.573      0.567      -0.023       0.043
# RetailPSqMi          0.0138      0.005      2.905      0.004       0.004       0.023
# pMale                0.1862      0.070      2.658      0.008       0.049       0.324
# VacantHU             0.3007      0.071      4.216      0.000       0.161       0.441
# gcn_ae_embed_0      47.8632     29.296      1.634      0.103      -9.712     105.439
# gcn_ae_embed_1       4.5103     20.799      0.217      0.828     -36.367      45.387
# gcn_ae_embed_2     -28.5540     21.037     -1.357      0.175     -69.898      12.790
# gcn_ae_embed_3     123.9394    107.758      1.150      0.251     -87.841     335.719
# gcn_ae_embed_4      33.1854     23.383      1.419      0.157     -12.770      79.141
# gcn_ae_embed_5      41.0569     77.601      0.529      0.597    -111.454     193.568
# gcn_ae_embed_6     -27.7719     17.618     -1.576      0.116     -62.397       6.853
# gcn_ae_embed_7     -22.6696     15.686     -1.445      0.149     -53.498       8.159
# gcn_ae_embed_8     -15.8246     25.865     -0.612      0.541     -66.658      35.009
# gcn_ae_embed_9      -0.0647     19.039     -0.003      0.997     -37.483      37.354
# gcn_ae_embed_10    -20.7525     20.748     -1.000      0.318     -61.528      20.023
# gcn_ae_embed_11    -23.4901     20.173     -1.164      0.245     -63.137      16.156
# gcn_ae_embed_12     -6.6624     27.346     -0.244      0.808     -60.407      47.083
# gcn_ae_embed_13    -46.8099     20.904     -2.239      0.026     -87.892      -5.727
# gcn_ae_embed_14    -17.3503     21.648     -0.801      0.423     -59.895      25.194
# gcn_ae_embed_15     29.9696     31.958      0.938      0.349     -32.838      92.778
# gcn_ae_embed_16     68.0722     29.868      2.279      0.023       9.371     126.774
+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
res_gcn_ae = y - fit_gcn_ae.fittedvalues
moran_I = Moran(res_gcn_ae.values, queen)
aic = fit_gcn_ae.aic
print(f'Embedding dim {dim}: AIC={aic:.2f}, Moran I={moran_I.I:.4f}, p-value={moran_I.p_sim:.4f}')
# Out:
# Embedding dim 128: AIC=4119.28, Moran I=0.0042, p-value=0.3800

# %%
plot_moran(Moran(res_gcn_ae.values, queen), zstandard=True)
plt.title(f'Moran Plot of Residuals (GCN AE dim {dim})')
plt.show()

# %% [markdown]
# #### Step 3: Run Final Optimized Model
# After selecting the best embedding size (lowest residual Moran's I and competitive AIC), we retrain the GCN autoencoder with this size and use the resulting embeddings as features in the final OLS regression.

# %%
# Final model: set best_dim to the optimal embedding size found above (e.g., best_dim = 48)
best_dim = 48  # Replace with your selected value from grid search
model = GCN_AE(x.shape[1], best_dim)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
for epoch in range(200):
    model.train()
    optimizer.zero_grad()
    x_hat, z = model(x, edge_index)
    loss = F.mse_loss(x_hat, x)
    loss.backward()
    optimizer.step()
embeddings = z.detach().numpy()
for i in range(embeddings.shape[1]):
    gdf[f'gcn_ae_embed_{i}'] = embeddings[:, i]
X_gcn_ae = add_constant(gdf[XVars + [f'gcn_ae_embed_{i}' for i in range(embeddings.shape[1])]])
fit_gcn_ae = OLS(y, X_gcn_ae).fit()
print(fit_gcn_ae.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               DrunkP1k   R-squared:                       0.530
# Model:                            OLS   Adj. R-squared:                  0.483
# Method:                 Least Squares   F-statistic:                     11.15
# Date:                Tue, 14 Jul 2026   Prob (F-statistic):           2.81e-57
# Time:                        01:29:57   Log-Likelihood:                -2031.5
# No. Observations:                 577   AIC:                             4171.
# Df Residuals:                     523   BIC:                             4406.
# Df Model:                          53
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const             -16.8678      9.206     -1.832      0.067     -34.954       1.218
# pHHPov              0.0407      0.051      0.803      0.422      -0.059       0.140
# BarPSqMi            0.0286      0.015      1.964      0.050   -9.25e-06       0.057
# RetailPSqMi         0.0165      0.004      3.854      0.000       0.008       0.025
# pMale               0.2060      0.069      3.007      0.003       0.071       0.341
# VacantHU            0.2436      0.066      3.680      0.000       0.114       0.374
# gcn_ae_embed_0     31.9252     17.173      1.859      0.064      -1.810      65.661
# gcn_ae_embed_1     -6.1891      7.808     -0.793      0.428     -21.528       9.150
# gcn_ae_embed_2    -20.3395     18.884     -1.077      0.282     -57.437      16.758
# gcn_ae_embed_3     31.7927     17.809      1.785      0.075      -3.193      66.778
# gcn_ae_embed_4      3.3611      8.748      0.384      0.701     -13.825      20.547
# gcn_ae_embed_5    -24.9827      6.640     -3.762      0.000     -38.028     -11.938
# gcn_ae_embed_6     14.6444     14.020      1.045      0.297     -12.898      42.187
# gcn_ae_embed_7    -17.9001      9.129     -1.961      0.050     -35.834       0.034
# gcn_ae_embed_8     28.2303     12.229      2.308      0.021       4.206      52.255
# gcn_ae_embed_9    -68.5749     29.668     -2.311      0.021    -126.859     -10.291
# gcn_ae_embed_10     7.7205     17.645      0.438      0.662     -26.944      42.385
# gcn_ae_embed_11    -7.4424      9.236     -0.806      0.421     -25.586      10.701
# gcn_ae_embed_12   -14.5171      6.274     -2.314      0.021     -26.843      -2.191
# gcn_ae_embed_13    57.2106     18.914      3.025      0.003      20.054      94.367
+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Compute residuals and Moran's I for final GCN AE model
res_gcn_ae = y - fit_gcn_ae.fittedvalues
moran = Moran(res_gcn_ae.values, queen)
print(f'Residual Moran I (final GCN AE): {moran.I:.4f}, p-value: {moran.p_sim:.4f}')
# Out:
# Residual Moran I (final GCN AE): 0.0212, p-value: 0.1650

# %%
# Plot Moran's I of residuals for final GCN AE model
plot_moran(Moran(res_gcn_ae.values, queen), zstandard=True)
plt.title('Moran Plot of Residuals (Final GCN AE)')
plt.show()

# %% [markdown]
# # Model Comparison and Summary
# In this section, we compare all fitted models (including baseline, spatial features, and VIF-selected models) using AIC and Moran's I of residuals.

# %%
# Summary of fit metrics and Moran's I for all models (R_squared, R_squared_adjusted, and AIC)
summary_rows = []

try:
    summary_rows.append({
        'Model': 'Baseline OLS',
        'R_squared': fit.rsquared,
        'R_squared_adj': fit.rsquared_adj,
        'AIC': fit.aic,
        'Moran I': moran_baseline.I,
        'p-value': moran_baseline.p_sim
    })
except Exception:
    pass

try:
    summary_rows.append({
        'Model': 'Coordinates',
        'R_squared': fit_coord.rsquared,
        'R_squared_adj': fit_coord.rsquared_adj,
        'AIC': fit_coord.aic,
        'Moran I': moran_coord.I,
        'p-value': moran_coord.p_sim
    })
except Exception:
    pass

try:
    summary_rows.append({
        'Model': 'Spatial Lag',
        'R_squared': fit_lag.rsquared,
        'R_squared_adj': fit_lag.rsquared_adj,
        'AIC': fit_lag.aic,
        'Moran I': moran_lag.I,
        'p-value': moran_lag.p_sim
    })
except Exception:
    pass

try:
    summary_rows.append({
        'Model': 'MESF',
        'R_squared': fit_mesf.rsquared,
        'R_squared_adj': fit_mesf.rsquared_adj,
        'AIC': fit_mesf.aic,
        'Moran I': moran_mesf.I,
        'p-value': moran_mesf.p_sim
    })
except Exception:
    pass

try:
    summary_rows.append({
        'Model': 'GCN AE',
        'R_squared': fit_gcn_ae.rsquared,
        'R_squared_adj': fit_gcn_ae.rsquared_adj,
        'AIC': fit_gcn_ae.aic,
        'Moran I': moran.I,
        'p-value': moran.p_sim
    })
except Exception:
    pass

summary = pd.DataFrame(summary_rows)
print(summary)
# Out:
#           Model  R_squared  R_squared_adj          AIC   Moran I  p-value
# 0  Baseline OLS   0.286206       0.279956  4316.672765  0.222444    0.001
# 1   Coordinates   0.290205       0.281472  4317.431778  0.223220    0.001
# 2   Spatial Lag   0.328436       0.316571  4291.485016  0.197063    0.001
# 3          MESF   0.478230       0.423149  4235.859643  0.016701    0.207
# 4        GCN AE   0.530478       0.482897  4170.979905  0.021193    0.165

# %% [markdown]
# ### Reading the comparison
#
# Each feature family is judged by the **residual Moran's I** (should fall toward 0) and
# model fit. On this data the baseline OLS leaves strong residual autocorrelation
# (Moran's I ≈ 0.22, p = 0.001). Raw **coordinates** barely help; **spatial lags** trim it;
# **MESF** all but removes it (Moran's I ≈ 0.02, p ≈ 0.22) while lifting $R^2$; the **GCN
# embeddings** fit best. Feature engineering thus makes dependence explicit *without*
# leaving the familiar OLS toolbox.
#
# **Lesson —** spatial feature engineering is model-agnostic and cheap, but you must
# *measure* it: track the residual Moran's I across feature sets and keep the ones that
# actually push it toward zero — a better $R^2$ with autocorrelated residuals is a mirage.
